# %%
import geopy 
from geopy.geocoders import Bing
from geopy.geocoders import Nominatim
import geopandas
import pandas as pd
from time import sleep

# %%
#Read in the patient addresses
patients = pd.read_csv('patient_addresses.csv', encoding='latin-1')

#Read in the care center addresses
care_centers = pd.read_csv('ng_locations.csv', encoding='latin-1')

#Take a look at the dataset
care_centers
# Out:
#                             NG Location Name  \
# 0                      Timber Ridge At Talus
# 1    Briarwood Health Center At Timber Ridge
# 2     Ear Nose Throat And Allergy Associates
# 3                    Hillside Surgery Center
# 4           Seattle Home Health Care Service
# ..                                       ...
# 306          Life Care At Home Of Washington
# 307                    Signature Home Health
# 308                   St Francis Hospital IP
# 309                   St Francis Hospital OP
# 310                           OPA Snoqualmie
#
#                                      NG Address        NG Address Line 1  \
# 0    100 Timber Ridge Way Ne Issaquah, WA 98027  100 Timber Ridge Way Ne
# 1    100 Timber Ridge Way NW Issaquah, WA 98027  100 Timber Ridge Way NW
# 2            104 27th Ave SE Puyallup, WA 98374          104 27th Ave SE
# 3            104 27th Ave SE Puyallup, WA 98374          104 27th Ave SE
# 4             115 NE 100th St Seattle, WA 98125          115 NE 100th St
# ..                                          ...                      ...
# 306       33600 6th Ave S Federal Way, WA 98003          33600 6th Ave S
# 307       33710 9th Ave S Federal Way, WA 98003          33710 9th Ave S
# 308       34503 9th Ave S Federal Way, WA 98003          34503 9th Ave S
# 309       34503 9th Ave S Federal Way, WA 98003          34503 9th Ave S
# 310       37624 Se Fury St Snoqualmie, WA 98065         37624 Se Fury St
#
#          NG City  NG ZIP NG State
# 0       Issaquah   98027       WA
# 1       Issaquah   98027       WA
# 2       Puyallup   98374       WA
# 3       Puyallup   98374       WA
# 4        Seattle   98125       WA
# ..           ...     ...      ...
# 306  Federal Way   98003       WA
# 307  Federal Way   98003       WA
# 308  Federal Way   98003       WA
# 309  Federal Way   98003       WA
# 310   Snoqualmie   98065       WA
#
# [311 rows x 6 columns]

# %%
#Enter the Bing Maps api key below. If you need a new api key, log-in here to create one: https://www.microsoft.com/en-us/maps/create-a-bing-maps-key
geolocator = Bing(api_key = 'AuV8RR8Xc-ouAlHUiXofmhkHOP5GUBtk5xieRB_48Zs5oVFusZM2R8WTlnLar7QN')



#location = geolocator.geocode(query="5904 W 5th Ave Kennewick, WA 99336", exactly_one=False)
#location
# Out:
# [Location(5904 W 5th Ave, Kennewick, WA 99336, United States, (46.2044681, -119.2001763, 0.0))]

# %%
#Function to convert NG Address to Lat/Lon 

def get_lat_lon(address):
    try:
        coordinates = geolocator.geocode(query=address)
        

    #If we get an error, skip to the next address
    except (geopy.exc.GeocoderUnavailable, geopy.exc.GeocoderServiceError):
        sleep(1)
        return 'NULL'
        
    
    #Wait for one second before performing request again (this helps avoid timeout issues)
    sleep(1)
    
    #Return the lat/lon coordinates
    return coordinates

# %%
#Convert the addresses to lat/lon (this takes up to 10 minutes to run)
care_centers['Geocoded_address'] = care_centers['NG Address'].apply(lambda x: get_lat_lon(x))

# %%
#Function for getting the lats
def get_lat(address):
    if address:
        return address[-1][0]
    else:
        return None

# %%
#Function for getting the lons
def get_lon(address):
    if address:
        return address[-1][1]
    else:
        return None

# %%
#Create the lat/lon columns
care_centers['lat'] = care_centers['Geocoded_address'].apply(lambda x: get_lat(x))
care_centers['lon'] = care_centers['Geocoded_address'].apply(lambda x: get_lon(x))

# %%
#View the results
care_centers
# Out:
#                             NG Location Name  \
# 0                      Timber Ridge At Talus
# 1    Briarwood Health Center At Timber Ridge
# 2     Ear Nose Throat And Allergy Associates
# 3                    Hillside Surgery Center
# 4           Seattle Home Health Care Service
# ..                                       ...
# 306          Life Care At Home Of Washington
# 307                    Signature Home Health
# 308                   St Francis Hospital IP
# 309                   St Francis Hospital OP
# 310                           OPA Snoqualmie
#
#                                      NG Address        NG Address Line 1  \
# 0    100 Timber Ridge Way Ne Issaquah, WA 98027  100 Timber Ridge Way Ne
# 1    100 Timber Ridge Way NW Issaquah, WA 98027  100 Timber Ridge Way NW
# 2            104 27th Ave SE Puyallup, WA 98374          104 27th Ave SE
# 3            104 27th Ave SE Puyallup, WA 98374          104 27th Ave SE
# 4             115 NE 100th St Seattle, WA 98125          115 NE 100th St
# ..                                          ...                      ...
# 306       33600 6th Ave S Federal Way, WA 98003          33600 6th Ave S
# 307       33710 9th Ave S Federal Way, WA 98003          33710 9th Ave S
# 308       34503 9th Ave S Federal Way, WA 98003          34503 9th Ave S
# 309       34503 9th Ave S Federal Way, WA 98003          34503 9th Ave S
# 310       37624 Se Fury St Snoqualmie, WA 98065         37624 Se Fury St
#
#          NG City  NG ZIP NG State  \
# 0       Issaquah   98027       WA
# 1       Issaquah   98027       WA
# 2       Puyallup   98374       WA
# 3       Puyallup   98374       WA
# 4        Seattle   98125       WA
# ..           ...     ...      ...
# 306  Federal Way   98003       WA
# 307  Federal Way   98003       WA
# 308  Federal Way   98003       WA
# 309  Federal Way   98003       WA
# 310   Snoqualmie   98065       WA
#
#                                       Geocoded_address        lat         lon
# 0    (100 Timber Ridge Way NW, Issaquah, WA 98027, ...  47.531573 -122.066264
# 1    (100 Timber Ridge Way NW, Issaquah, WA 98027, ...  47.531573 -122.066264
# 2    (104 27th Ave SE, Puyallup, WA 98374, United S...  47.165267 -122.292678
# 3    (104 27th Ave SE, Puyallup, WA 98374, United S...  47.165267 -122.292678
# 4    (115 NE 100th St, Seattle, WA 98125, United St...  47.700816 -122.327198
# ..                                                 ...        ...         ...
# 306  (33600 6th Ave S, Federal Way, WA 98003, Unite...  47.299954 -122.324920
# 307  (33710 9th Ave S, Federal Way, WA 98003, Unite...  47.299418 -122.322076
# 308  (34503 9th Ave S, Federal Way, WA 98003, Unite...  47.292942 -122.323748
# 309  (34503 9th Ave S, Federal Way, WA 98003, Unite...  47.292942 -122.323748
# 310  (37624 SE Fury St, Snoqualmie, WA 98065, Unite...  47.533999 -121.838273
#
# [311 rows x 9 columns]

# %%
care_centers['lat'].isnull().sum()
# Out:
# 0

# %%
#Export as a CSV
care_centers.to_csv('bing_care_center_lat_lons.csv', index=False)
