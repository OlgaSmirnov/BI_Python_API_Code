# %% [markdown]
# # Helper functions test

# %%
import helper_functions

# %%
#Authenticate function
#helper_functions.authenticate()

# %%
#Get available reports function
#helper_functions.get_available_reports()

# %%
#Get report key function
report_file_path = "/content/folder[@name='zzzCompany Folders']/folder[@name='Proliance Surgeons, Inc., P.S.']/folder[@name='UltiPro']/folder[@name='Export to SQL']/report[@name='Pre-Check Master']"
report_key = helper_functions.get_report_key(report_file_path)

# %%
#Get report function
helper_functions.retrieve_report(report_key)
# Out:
#       period_control_date period_control      period_end_date employee_number  \
# 0     2022-11-25T00:00:00      202211251  2022-11-19T00:00:00       000000184
# 1     2022-11-25T00:00:00      202211251  2022-11-19T00:00:00       000000226
# 2     2022-11-25T00:00:00      202211251  2022-11-19T00:00:00       000000255
# 3     2022-11-25T00:00:00      202211251  2022-11-19T00:00:00       000000273
# 4     2022-11-25T00:00:00      202211251  2022-11-19T00:00:00       000000290
# ...                   ...            ...                  ...             ...
# 2208  2022-11-25T00:00:00      202211251  2022-11-19T00:00:00       001008598
# 2209  2022-11-25T00:00:00      202211251  2022-11-19T00:00:00       001008599
# 2210  2022-11-25T00:00:00      202211251  2022-11-19T00:00:00       001008600
# 2211  2022-11-25T00:00:00      202211251  2022-11-19T00:00:00       001008603
# 2212  2022-11-25T00:00:00      202211251  2022-11-19T00:00:00       001008605
#
# ...

# %%
helper_functions.get_available_precheck_reports()
# Out:
#                     ReportName  \
# 61         Pre-Check Deduction
# 62          Pre-Check Earnings
# 63            Pre-Check Master
# 64  Pre-Check Payroll Register
# 65               Pre-Check Tax
# 66                     Prenote
#
#                                            ReportPath
# 61  /content/folder[@name='zzzCompany Folders']/fo...
# 62  /content/folder[@name='zzzCompany Folders']/fo...
# 63  /content/folder[@name='zzzCompany Folders']/fo...
# 64  /content/folder[@name='zzzCompany Folders']/fo...
# 65  /content/folder[@name='zzzCompany Folders']/fo...
# 66  /content/folder[@name='zzzCompany Folders']/fo...
