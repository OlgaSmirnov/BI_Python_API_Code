# %%
#Import our libraries
import time
import requests
import json
import xml.etree.ElementTree as ET  # for parsing XML
import xmltodict
import pandas as pd
import csv
import base64 
import pyodbc
import sqlalchemy as sal
from sqlalchemy import create_engine
from sqlalchemy.types import NVARCHAR

#Import our helper functions
import helper_functions

# Step 1: Get the report file path that we need
report_path = helper_functions.get_report_file_path('Employee List')

## Step 2: Retrieve the report
df = helper_functions.retrieve_report(report_path) 

df
# Out:
#               pay_group ssn_(unformatted) employee_number  \
# 0       Hourly BiWeekly         534118377       001003651
# 1       Hourly BiWeekly         534153592       001007204
# 2       Hourly BiWeekly         607574894       001004881
# 3     Salaried Biweekly         531965588       001008549
# 4       Hourly BiWeekly         535045731       001001279
# ...                 ...               ...             ...
# 9581    Hourly BiWeekly         605583592       001004641
# 9582    Hourly BiWeekly         179501094       001005696
# 9583    Hourly BiWeekly         534116910       001006118
# 9584    Hourly BiWeekly         531374469       001006766
# 9585    Hourly BiWeekly         531191143       001000142
#
#      employee_name_(last_suffix,_first_mi) address_line_1_+_address_line_2  \
# 0                       Aarestad_ Heidi H.                7320 Highland Dr
# 1                         Aasal_ Ashley E.                22500 10th Ave S
# 2                Abad_ Queen Jacqueline D.              306 Kirkland Pl SE
# 3                        Abafo_ Johanna A.               18216 132nd Pl SE
# 4                       Abalahin_ Julie A.           10721 MT Tacoma Dr SW
# ...                                    ...                             ...
# 9581                       Zuniga_ Maritza                   210 S 18th St
# 9582                       Zweber_ Mary F.                 8204 Beverly Ln
# 9583                      Zwicky_ Amber D.                 5209 NE 10th Pl
# 9584                      Zwolski_ Jane E.       12910 SE 240th ST Unit B4
# 9585                     Zyskowski_ Amy C.              17026 122nd Ave SE
#
#               city state zip_code                     email_address  \
# 0          Everett    WA    98203           heidiaarestad@gmail.com
# 1       Des Moines    WA    98198     A.Aasal@proliancesurgeons.com
# 2           Renton    WA    98056
# 3           Renton    WA    98058     j.abafo@proliancesurgeons.com
# 4           Tacoma    WA    98498  j.abalahin@proliancesurgeons.com
# ...            ...   ...      ...                               ...
# 9581  Mount Vernon    WA    98274    M.Zuniga@proliancesurgeons.com
# 9582       Everett    WA    98203    M.Zweber@proliancesurgeons.com
# 9583        Renton    WA    98059    A.Zwicky@proliancesurgeons.com
# 9584          Kent    WA    98031   J.Hackett@proliancesurgeons.com
# 9585        Renton    WA    98058
#
#               alternate_email  ... org_level_3_code     termination_date  \
# 0                              ...              000  2020-05-08 00:00:00
# 1     ashleydamon24@gmail.com  ...              000
# 2                              ...              000  2017-03-28 00:00:00
# 3        amoraj1434@gmail.com  ...              000
# 4                              ...              000  2021-06-04 00:00:00
# ...                       ...  ...              ...                  ...
# 9581                           ...              000  2019-05-03 00:00:00
# 9582                           ...              000  2018-07-20 00:00:00
# 9583                           ...              000  2019-05-31 00:00:00
# 9584    janezwolski@gmail.com  ...              000
# 9585                           ...              000  2006-01-27 00:00:00
#
#             first_name  last_name middle_name  \
# 0                Heidi   Aarestad           H
# 1               Ashley      Aasal           E
# 2     Queen Jacqueline       Abad           D
# 3              Johanna      Abafo           A
# 4                Julie   Abalahin           A
# ...                ...        ...         ...
# 9581           Maritza     Zuniga
# 9582              Mary     Zweber           F
# 9583             Amber     Zwicky           D
# 9584              Jane    Zwolski           E
# 9585               Amy  Zyskowski           C
#
#      supervisor_name_(first_mi_last_suffix) supervisor_employee_number  \
# 0                         Shelly K. Peltier                  000250048
# 1                       Jessica L. Weathers                  000260032
# 2
# 3                         Erik M. Mortensen                  001006786
# 4
# ...                                     ...                        ...
# 9581
# 9582
# 9583                      Julia V. Stefoglo                  001003126
# 9584                      Sarah L. Peterson                  001005009
# 9585
#
#                supervisor_email_address                 location location_code
# 0       S.Peltier@proliancesurgeons.com                     EDOC        002500
# 1      J.Weathers@proliancesurgeons.com    CSO - Payment Posting        000181
# 2                                                           PRET        001600
# 3     E.Mortensen@proliancesurgeons.com                PRS - ASC        002601
# 4                                             PSO - Lakewood ASC        007301
# ...                                 ...                      ...           ...
# 9581                                                        CENT        006700
# 9582                                     OSS - Ortho Clinic Tall        000200
# 9583   J.Stefoglo@proliancesurgeons.com               PRET - ASC        001601
# 9584  SL.Peterson@proliancesurgeons.com                     NWWH        004300
# 9585                                                Z-DO NOT USE           028
#
# [9586 rows x 35 columns]

# %%
# Step 3: Export the report to a CSV file
df.to_csv('ukg_bulk_insert.csv', index=False)

# %%
# Step 4: Insert the report into BiData2 as a table
helper_functions.create_sql_table_v2('STG_EmployeeList')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\37\ipykernel_21228\3161702322.py in <module>
#       1 # Step 4: Insert the report into BiData2 as a table
# ----> 2 helper_functions.create_sql_table_v2('STG_EmployeeList')
#
# c:\UKG\Reports as a service\Precheck\helper_functions.py in create_sql_table_v2(table_name)
#     537
#     538     #Re-populate the table
# --> 539     cursor.execute(
#     540         r"""
#     541         -- import the file
#
# ProgrammingError: ('42000', '[42000] [Microsoft][ODBC SQL Server Driver][SQL Server]Bulk load: An unexpected end of file was encountered in the data file. (4832) (SQLExecDirectW); [42000] [Microsoft][ODBC SQL Server Driver][SQL Server]The OLE DB provider "BULK" for linked server "(null)" reported an error. The provider did not give any information about the error. (7399); [42000] [Microsoft][ODBC SQL Server Driver][SQL Server]Cannot fetch a row from OLE DB provider "BULK" for linked server "(null)". (7330)')

# %%
# Step 5: Close the API connection
helper_functions.close_api_connection()
