# %%
#Import our libraries
import time
import requests
import json
import xml.etree.ElementTree as ET  # for parsing XML
import xmltodict
import pandas as pd
import csv
import base64 
import sqlalchemy

#Import our helper functions
import helper_functions

# %% [markdown]
# # Step 1: View the list of reports available

# %%
report_lst = helper_functions.get_available_reports()

# %%
#Turn it into a list to see all of them
list(report_lst['ReportName'])
# Out:
# ['_Current Employee Deductions and Benefits',
#  '2013-03-05T21:47:40.188Z',
#  '2020-10-26T18:25:32.678Z',
#  '2021 Allocation Report (1)',
#  '401k Allocation Report V1',
#  '401k Allocation Report V2',
#  '401k Allocation Report V2_UKG',
#  '401k Allocation Report V3_UKG',
#  '401k Allocation Report V3_UKG v2',
#  '401k Allocation Report V3_UKG v4',
#  '5 Level Supervisors',
#  'Active EE_DD List',
#  'Allocated Hours FTE by Date',
#  'Allocated Hours FTE by Month',
#  'Annual Earnings',
#  'Audit Report with Time vs Pay Matrix Tables',
#  'Comp Project V3',
#  'Configuration Validation',
#  'Counts by Location',
#  'Current Employee Deductions and Benefits',
#  'Current Employee Deductions and Benefits v2',
#  'Current Employee Deductions and Benefits.TEST',
#  "David's Report",
#  "David's Report V2",
#  'Deduction list',
#  'Deduction Pay History By Deduction For EmployeesUKG',
#  'Deductions in Arrears V2',
#  'Deferred Comp Wages and Hours_UKG',
#  'Dependents by Employee and Plan test',
#  'Document Category Report',
#  'DSHS_New Hires',
#  'Earning Codes Table',
#  'Earnings Pay History By Earning Code For Employees_ULTI',
#  'Earnings_by_Code',
#  'Earnings_with_PayPeriodID_TEST',
#  'EE Holiday List',
#  'EE Location List',
#  'Employee job history report',
#  'Employee List',
#  'Employee Location Changes v2',
#  'Employee PTO History - Balances - Updated 2',
#  'Employee Waived Deductions',
#  'EmployeeAllocation',
#  'Employees Not Clocked In for the Day',
#  'FSA EE Contribution Report - ded-payroll stop utility',
#  'FTE List',
#  'HASER Contributions v2',
#  'Job Code',
#  'Joel Report',
#  'Labels - New Hires',
#  'Labor Distribution',
#  'Labor Distribution by EE',
#  'Locations',
#  'Locations',
#  'Locations',
#  'Locations Address',
#  'Org levels (business units)',
#  'Organizational Levels',
#  'Overtime Report',
#  'Pay Period',
#  'Pay Period (1)',
#  'PayCheck summary TEST',
#  'Pending Requests',
#  'Point In TimeUKG',
#  'Pre-Check Deduction',
#  'Pre-Check Earnings',
#  'Pre-Check Master',
#  'Pre-Check Payroll Register',
#  'Pre-Check Tax',
#  'Prenote',
#  'Pro-rate for Salaried New',
#  'Pro-rate for Salaried Term',
#  'Report with Declined Coverage Reason',
#  'Report with Declined Coverage Reason with Term',
#  'SSN Verification',
#  'Test didactions',
#  'Test enrollments',
#  'UNUM Benefit Billing By Provider Report',
#  'Active Benefits (1)',
#  'HSA Contribution Report']

# %%
#Get the precheck deduction report pathname
report_lst[report_lst['ReportName'].str.contains('pre', regex=True, case=False)]
# Out:
#                     ReportName  \
# 64         Pre-Check Deduction
# 65          Pre-Check Earnings
# 66            Pre-Check Master
# 67  Pre-Check Payroll Register
# 68               Pre-Check Tax
# 69                     Prenote
#
#                                            ReportPath
# 64  /content/folder[@name='zzzCompany Folders']/fo...
# 65  /content/folder[@name='zzzCompany Folders']/fo...
# 66  /content/folder[@name='zzzCompany Folders']/fo...
# 67  /content/folder[@name='zzzCompany Folders']/fo...
# 68  /content/folder[@name='zzzCompany Folders']/fo...
# 69  /content/folder[@name='zzzCompany Folders']/fo...

# %%
report_path = report_lst[report_lst['ReportName'] == 'Pre-Check Tax']['ReportPath'].loc[68]
report_path
# Out:
# "/content/folder[@name='zzzCompany Folders']/folder[@name='Proliance Surgeons, Inc., P.S.']/folder[@name='UltiPro']/folder[@name='Export to SQL']/report[@name='Pre-Check Tax']"

# %% [markdown]
# ## Step 2: Retrieve the report

# %%
df = helper_functions.retrieve_report(report_path) 
df
# Out:
# c:\UKG\Reports as a service\Precheck\helper_functions.py:367: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col] = df[col].astype(str).str.replace('{', '')
# c:\UKG\Reports as a service\Precheck\helper_functions.py:368: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col] = df[col].astype(str).str.replace('}', '')
# c:\UKG\Reports as a service\Precheck\helper_functions.py:369: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col] = df[col].astype(str).str.replace('[', '')
# c:\UKG\Reports as a service\Precheck\helper_functions.py:370: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col] = df[col].astype(str).str.replace(']', '')
#     period_control_date employee_number                stub_description  \
# 0   2023-01-20T00:00:00       000310305               Employee Medicare
# 1   2023-01-20T00:00:00       000310305               Employer Medicare
# 2   2023-01-20T00:00:00       000310305              Federal Income Tax
# 3   2023-01-20T00:00:00       000310305        Federal Unemployment Tax
# 4   2023-01-20T00:00:00       000310305    Social Security Employee Tax
# 5   2023-01-20T00:00:00       000310305    Social Security Employer Tax
# 6   2023-01-20T00:00:00       000310305   WA Labor & Ind EE Withholding
# 7   2023-01-20T00:00:00       000310305       WA Labor & Ind ER Expense
# 8   2023-01-20T00:00:00       000310305        WA Paid Family Leave- EE
# 9   2023-01-20T00:00:00       000310305  WA Paid Family Leave- ER pd EE
# 10  2023-01-20T00:00:00       000310305       WA Paid Medical Leave- EE
# 11  2023-01-20T00:00:00       000310305       WA Paid Medical Leave- ER
# 12  2023-01-20T00:00:00       000310305             WA State Income Tax
# 13  2023-01-20T00:00:00       000310305        WA Unemployment Employer
# 14  2023-01-20T00:00:00       000310305       WA Vol Paid Fam Leave- EE
# 15  2023-01-20T00:00:00       000310305  WA Vol Paid Fam Leave-ER pd EE
# 16  2023-01-20T00:00:00       000310305       WA Vol Paid Med Leave- EE
# 17  2023-01-20T00:00:00       000310305       WA Vol Paid Med Leave- ER
# 18  2023-01-20T00:00:00       000310305  WA Workforce Training Employer
# 19  2023-01-20T00:00:00       000310305           Washington Cares Fund
# 20  2023-01-20T00:00:00       001008227               Employee Medicare
# 21  2023-01-20T00:00:00       001008227               Employer Medicare
# 22  2023-01-20T00:00:00       001008227              Federal Income Tax
# 23  2023-01-20T00:00:00       001008227        Federal Unemployment Tax
# 24  2023-01-20T00:00:00       001008227    Social Security Employee Tax
# 25  2023-01-20T00:00:00       001008227    Social Security Employer Tax
# 26  2023-01-20T00:00:00       001008227   WA Labor & Ind EE Withholding
# 27  2023-01-20T00:00:00       001008227       WA Labor & Ind ER Expense
# 14  WAVPFLEE       WA Vol Paid Fam Leave- EE             TG      SDI
# 15  WAVPFLEP  WA Vol Paid Fam Leave-ER pd EE             TG      SDI
# 16  WAVPMLEE       WA Vol Paid Med Leave- EE             TG      SDI
# 17  WAVPMLER       WA Vol Paid Med Leave- ER             TG      SDI
# 18   WAWTFER  WA Workforce Training Employer             TG      SUI
# 19   WACRFEE           Washington Cares Fund             TG      SDI
# 20   USMEDEE               Employee Medicare             TG      MED
# 21   USMEDER               Employer Medicare             TG      MED
# 22     USFIT              Federal Income Tax             TG      FIT
# 23    USFUTA        Federal Unemployment Tax             TG      FUT
# 24   USSOCEE    Social Security Employee Tax             TG      SOC
# 25   USSOCER    Social Security Employer Tax             TG      SOC
# 26    WALIEE   WA Labor & Ind EE Withholding             TG      LIT
# 27    WALIER       WA Labor & Ind ER Expense             TG      LIT
# 28   WAPFLEE        WA Paid Family Leave- EE             TG      SDI
# 29   WAPFLEP  WA Paid Family Leave- ER pd EE             TG      SDI
# 30   WAPMLEE       WA Paid Medical Leave- EE             TG      SDI
# 31   WAPMLER       WA Paid Medical Leave- ER             TG      SDI
# 32     WASIT             WA State Income Tax             TG      SIT
# 33   WASUIER        WA Unemployment Employer             TG      SUI
# 34  WAVPFLEE       WA Vol Paid Fam Leave- EE             TG      SDI
# 35  WAVPFLEP  WA Vol Paid Fam Leave-ER pd EE             TG      SDI
# 36  WAVPMLEE       WA Vol Paid Med Leave- EE             TG      SDI
# 37  WAVPMLER       WA Vol Paid Med Leave- ER             TG      SDI
# 38   WAWTFER  WA Workforce Training Employer             TG      SUI
# 39   WACRFEE           Washington Cares Fund             TG      SDI
# 40   USMEDEE               Employee Medicare             TG      MED
# 41   USMEDER               Employer Medicare             TG      MED
# 42     USFIT              Federal Income Tax             TG      FIT
# 43    USFUTA        Federal Unemployment Tax             TG      FUT
# 44   USSOCEE    Social Security Employee Tax             TG      SOC
# 45   USSOCER    Social Security Employer Tax             TG      SOC
# 46    WALIEE   WA Labor & Ind EE Withholding             TG      LIT
# 47    WALIER       WA Labor & Ind ER Expense             TG      LIT
# 48   WAPFLEE        WA Paid Family Leave- EE             TG      SDI
# 49   WAPFLEP  WA Paid Family Leave- ER pd EE             TG      SDI
# 50   WAPMLEE       WA Paid Medical Leave- EE             TG      SDI
# 51   WAPMLER       WA Paid Medical Leave- ER             TG      SDI
# 52     WASIT             WA State Income Tax             TG      SIT
# 53   WASUIER        WA Unemployment Employer             TG      SUI
# 54  WAVPFLEE       WA Vol Paid Fam Leave- EE             TG      SDI
# 55  WAVPFLEP  WA Vol Paid Fam Leave-ER pd EE             TG      SDI
# 56  WAVPMLEE       WA Vol Paid Med Leave- EE             TG      SDI
# 57  WAVPMLER       WA Vol Paid Med Leave- ER             TG      SDI
# 58   WAWTFER  WA Workforce Training Employer             TG      SUI
# 59   WACRFEE           Washington Cares Fund             TG      SDI
#
#    employer_tax current_taxable_gross current_tax_amount
# 0             N               3090.46              44.81
# 1             Y               3090.46              44.81
# 2             N               2626.89             130.77
# 3             Y               3090.46              18.54
# 4             N               3090.46             191.61
# 5             Y               3090.46             191.61
# 6             N               3090.46                  0
# 7             Y               3090.46                  0
# 8             N               3090.46              12.48
# 9             Y               3090.46                  0
# 10            N               3090.46               5.51
# 11            Y               3090.46               6.73
# 12            N               2626.89                  0
# 13            Y               3090.46              27.81
# 14            N                     0                  0
# 15            Y                     0                  0
# 16            N                     0                  0
# 17            Y                     0                  0
# 18            Y               3090.46               0.93
# 19            N                     0                  0
# 20            N                612.15               8.88
# 21            Y                612.15               8.88
# 22            N                612.15               7.95
# 23            Y                612.15               3.67
# 24            N                612.15              37.95
# 25            Y                612.15              37.95
# 26            N                612.15                  0
# 27            Y                612.15                  0
# 28            N                612.15               2.47
# 29            Y                612.15                  0
# 30            N                612.15               1.09
# 31            Y                612.15               1.34
# 32            N                612.15                  0
# 33            Y                612.15               5.51
# 34            N                     0                  0
# 35            Y                     0                  0
# 36            N                     0                  0
# 37            Y                     0                  0
# 38            Y                612.15               0.18
# 39            N                     0                  0
# 40            N               1129.04              16.37
# 41            Y               1129.04              16.37
# 42            N               1129.04                  0
# 43            Y               1129.04               6.78
# 44            N               1129.04              70.01
# 45            Y               1129.04              70.01
# 46            N               1191.54                  0
# 47            Y               1191.54                  0
# 48            N               1191.54               4.81
# 49            Y               1191.54                  0
# 50            N               1191.54               2.12
# 51            Y               1191.54                2.6
# 52            N               1129.04                  0
# 53            Y               1191.54              10.72
# 54            N                     0                  0
# 55            Y                     0                  0
# 56            N                     0                  0
# 57            Y                     0                  0
# 58            Y               1191.54               0.36
# 59            N                     0                  0

# %%
#Clean the columns
df['period_control_date'] = df['period_control_date'].str.replace('T', ' ')

#View the results
df
# Out:
#     period_control_date employee_number                stub_description  \
# 0   2023-01-20 00:00:00       000310305               Employee Medicare
# 1   2023-01-20 00:00:00       000310305               Employer Medicare
# 2   2023-01-20 00:00:00       000310305              Federal Income Tax
# 3   2023-01-20 00:00:00       000310305        Federal Unemployment Tax
# 4   2023-01-20 00:00:00       000310305    Social Security Employee Tax
# 5   2023-01-20 00:00:00       000310305    Social Security Employer Tax
# 6   2023-01-20 00:00:00       000310305   WA Labor & Ind EE Withholding
# 7   2023-01-20 00:00:00       000310305       WA Labor & Ind ER Expense
# 8   2023-01-20 00:00:00       000310305        WA Paid Family Leave- EE
# 9   2023-01-20 00:00:00       000310305  WA Paid Family Leave- ER pd EE
# 10  2023-01-20 00:00:00       000310305       WA Paid Medical Leave- EE
# 11  2023-01-20 00:00:00       000310305       WA Paid Medical Leave- ER
# 12  2023-01-20 00:00:00       000310305             WA State Income Tax
# 13  2023-01-20 00:00:00       000310305        WA Unemployment Employer
# 14  2023-01-20 00:00:00       000310305       WA Vol Paid Fam Leave- EE
# 15  2023-01-20 00:00:00       000310305  WA Vol Paid Fam Leave-ER pd EE
# 16  2023-01-20 00:00:00       000310305       WA Vol Paid Med Leave- EE
# 17  2023-01-20 00:00:00       000310305       WA Vol Paid Med Leave- ER
# 18  2023-01-20 00:00:00       000310305  WA Workforce Training Employer
# 19  2023-01-20 00:00:00       000310305           Washington Cares Fund
# 6     WALIEE   WA Labor & Ind EE Withholding             TG      LIT
# 7     WALIER       WA Labor & Ind ER Expense             TG      LIT
# 8    WAPFLEE        WA Paid Family Leave- EE             TG      SDI
# 9    WAPFLEP  WA Paid Family Leave- ER pd EE             TG      SDI
# 10   WAPMLEE       WA Paid Medical Leave- EE             TG      SDI
# 11   WAPMLER       WA Paid Medical Leave- ER             TG      SDI
# 12     WASIT             WA State Income Tax             TG      SIT
# 13   WASUIER        WA Unemployment Employer             TG      SUI
# 14  WAVPFLEE       WA Vol Paid Fam Leave- EE             TG      SDI
# 15  WAVPFLEP  WA Vol Paid Fam Leave-ER pd EE             TG      SDI
# 16  WAVPMLEE       WA Vol Paid Med Leave- EE             TG      SDI
# 17  WAVPMLER       WA Vol Paid Med Leave- ER             TG      SDI
# 18   WAWTFER  WA Workforce Training Employer             TG      SUI
# 19   WACRFEE           Washington Cares Fund             TG      SDI
# 20   USMEDEE               Employee Medicare             TG      MED
# 21   USMEDER               Employer Medicare             TG      MED
# 22     USFIT              Federal Income Tax             TG      FIT
# 23    USFUTA        Federal Unemployment Tax             TG      FUT
# 24   USSOCEE    Social Security Employee Tax             TG      SOC
# 25   USSOCER    Social Security Employer Tax             TG      SOC
# 26    WALIEE   WA Labor & Ind EE Withholding             TG      LIT
# 27    WALIER       WA Labor & Ind ER Expense             TG      LIT
# 28   WAPFLEE        WA Paid Family Leave- EE             TG      SDI
# 29   WAPFLEP  WA Paid Family Leave- ER pd EE             TG      SDI
# 30   WAPMLEE       WA Paid Medical Leave- EE             TG      SDI
# 31   WAPMLER       WA Paid Medical Leave- ER             TG      SDI
# 32     WASIT             WA State Income Tax             TG      SIT
# 33   WASUIER        WA Unemployment Employer             TG      SUI
# 34  WAVPFLEE       WA Vol Paid Fam Leave- EE             TG      SDI
# 35  WAVPFLEP  WA Vol Paid Fam Leave-ER pd EE             TG      SDI
# 36  WAVPMLEE       WA Vol Paid Med Leave- EE             TG      SDI
# 37  WAVPMLER       WA Vol Paid Med Leave- ER             TG      SDI
# 38   WAWTFER  WA Workforce Training Employer             TG      SUI
# 39   WACRFEE           Washington Cares Fund             TG      SDI
# 40   USMEDEE               Employee Medicare             TG      MED
# 41   USMEDER               Employer Medicare             TG      MED
# 42     USFIT              Federal Income Tax             TG      FIT
# 43    USFUTA        Federal Unemployment Tax             TG      FUT
# 44   USSOCEE    Social Security Employee Tax             TG      SOC
# 45   USSOCER    Social Security Employer Tax             TG      SOC
# 46    WALIEE   WA Labor & Ind EE Withholding             TG      LIT
# 47    WALIER       WA Labor & Ind ER Expense             TG      LIT
# 48   WAPFLEE        WA Paid Family Leave- EE             TG      SDI
# 49   WAPFLEP  WA Paid Family Leave- ER pd EE             TG      SDI
# 50   WAPMLEE       WA Paid Medical Leave- EE             TG      SDI
# 51   WAPMLER       WA Paid Medical Leave- ER             TG      SDI
# 52     WASIT             WA State Income Tax             TG      SIT
# 53   WASUIER        WA Unemployment Employer             TG      SUI
# 54  WAVPFLEE       WA Vol Paid Fam Leave- EE             TG      SDI
# 55  WAVPFLEP  WA Vol Paid Fam Leave-ER pd EE             TG      SDI
# 56  WAVPMLEE       WA Vol Paid Med Leave- EE             TG      SDI
# 57  WAVPMLER       WA Vol Paid Med Leave- ER             TG      SDI
# 58   WAWTFER  WA Workforce Training Employer             TG      SUI
# 59   WACRFEE           Washington Cares Fund             TG      SDI
#
#    employer_tax current_taxable_gross current_tax_amount
# 0             N               3090.46              44.81
# 1             Y               3090.46              44.81
# 2             N               2626.89             130.77
# 3             Y               3090.46              18.54
# 4             N               3090.46             191.61
# 5             Y               3090.46             191.61
# 6             N               3090.46                  0
# 7             Y               3090.46                  0
# 8             N               3090.46              12.48
# 9             Y               3090.46                  0
# 10            N               3090.46               5.51
# 11            Y               3090.46               6.73
# 12            N               2626.89                  0
# 13            Y               3090.46              27.81
# 14            N                     0                  0
# 15            Y                     0                  0
# 16            N                     0                  0
# 17            Y                     0                  0
# 18            Y               3090.46               0.93
# 19            N                     0                  0
# 20            N                612.15               8.88
# 21            Y                612.15               8.88
# 22            N                612.15               7.95
# 23            Y                612.15               3.67
# 24            N                612.15              37.95
# 25            Y                612.15              37.95
# 26            N                612.15                  0
# 27            Y                612.15                  0
# 28            N                612.15               2.47
# 29            Y                612.15                  0
# 30            N                612.15               1.09
# 31            Y                612.15               1.34
# 32            N                612.15                  0
# 33            Y                612.15               5.51
# 34            N                     0                  0
# 35            Y                     0                  0
# 36            N                     0                  0
# 37            Y                     0                  0
# 38            Y                612.15               0.18
# 39            N                     0                  0
# 40            N               1129.04              16.37
# 41            Y               1129.04              16.37
# 42            N               1129.04                  0
# 43            Y               1129.04               6.78
# 44            N               1129.04              70.01
# 45            Y               1129.04              70.01
# 46            N               1191.54                  0
# 47            Y               1191.54                  0
# 48            N               1191.54               4.81
# 49            Y               1191.54                  0
# 50            N               1191.54               2.12
# 51            Y               1191.54                2.6
# 52            N               1129.04                  0
# 53            Y               1191.54              10.72
# 54            N                     0                  0
# 55            Y                     0                  0
# 56            N                     0                  0
# 57            Y                     0                  0
# 58            Y               1191.54               0.36
# 59            N                     0                  0

# %% [markdown]
# # Step 3: Export the report as a CSV

# %%
df.to_csv('ukg_bulk_insert.csv', index=False)

# %% [markdown]
# # Step 4: Insert the report into BiData2 as a table

# %%
helper_functions.create_sql_table_v2('STG_PreCheck_Tax')

# %% [markdown]
# # Step 5: Close the API connection

# %%
helper_functions.close_api_connection()
# Out:
# '<s:Envelope xmlns:s="http://www.w3.org/2003/05/soap-envelope" xmlns:a="http://www.w3.org/2005/08/addressing"><s:Header><a:Action s:mustUnderstand="1">http://www.ultipro.com/dataservices/bidata/2/IBIDataService/LogOffResponse</a:Action></s:Header><s:Body><LogOffResponse xmlns="http://www.ultipro.com/dataservices/bidata/2"><LogOffResult xmlns:i="http://www.w3.org/2001/XMLSchema-instance"><ServiceId i:nil="true"/><ClientAccessKey>PLAB4</ClientAccessKey><Token i:nil="true"/><Status>LoggedOff</Status><StatusMessage i:nil="true"/><InstanceKey i:nil="true"/></LogOffResult></LogOffResponse></s:Body></s:Envelope>'
